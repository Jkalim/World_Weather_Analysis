# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=547a56208cfda6d721867a09dd8d30b5'

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1



# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | duminichi
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | rawson
# Processing Record 7 of Set 1 | flinders
# Processing Record 8 of Set 1 | kapoeta
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | naze
# Processing Record 12 of Set 1 | tabarqah
# City not found. Skipping...
# Processing Record 13 of Set 1 | new norfolk
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | goderich
# Processing Record 16 of Set 1 | saryshagan
# City not found. Skipping...
# Processing Record 17 of Set 1 | geraldton
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | tuktoyaktuk
# Processing Record 21 of Set 1 | khatanga
# Processing Record 22 of Set 1 | preeceville
# Processing Record 23 of Set 1 | suntar
# Processing Record 24 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | gangotri
# City not found. Skipping...
# Processing Record 27 of Set 1 | tura
# Processing Record 28 of Set 1 | ilulissat
# Processing Record 29 of Set 1 | east london
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | shalakusha
# Processing Record 32 of Set 1 | namibe
# Processing Record 33 of Set 1 | tahoua
# Processing Record 34 of Set 1 | vestmannaeyjar
# Processing Record 35 of Set 1 | mucurapo
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | chapais
# Processing Record 38 of Set 1 | hobyo
# Processing Record 39 of Set 1 | hohhot
# Processing Record 40 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 1 | bluff
# Processing Record 42 of Set 1 | dikson
# Processing Record 43 of Set 1 | kaitangata
# Processing Record 44 of Set 1 | sinnamary
# Processing Record 45 of Set 1 | esperance
# Processing Record 46 of Set 1 | georgetown
# Processing Record 47 of Set 1 | beloha
# Processing Record 48 of Set 1 | nikolskoye
# Processing Record 49 of Set 1 | hendijan
# City not found. Skipping...
# Processing Record 50 of Set 1 | bubaque
# Processing Record 1 of Set 2 | bronnoysund
# Processing Record 2 of Set 2 | yeppoon
# Processing Record 3 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 2 | jumla
# Processing Record 5 of Set 2 | fare
# Processing Record 6 of Set 2 | lagoa
# Processing Record 7 of Set 2 | rikitea
# Processing Record 8 of Set 2 | dombarovskiy
# Processing Record 9 of Set 2 | san jeronimo
# Processing Record 10 of Set 2 | saint george
# Processing Record 11 of Set 2 | khair
# Processing Record 12 of Set 2 | provideniya
# Processing Record 13 of Set 2 | hornepayne
# Processing Record 14 of Set 2 | sao joao da barra
# Processing Record 15 of Set 2 | ondorhaan
# City not found. Skipping...
# Processing Record 16 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 2 | korla
# Processing Record 18 of Set 2 | castro
# Processing Record 19 of Set 2 | verkhniy rohachyk
# Processing Record 20 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 2 | olafsvik
# Processing Record 22 of Set 2 | nanortalik
# Processing Record 23 of Set 2 | tasiilaq
# Processing Record 24 of Set 2 | hobart
# Processing Record 25 of Set 2 | pisco
# Processing Record 26 of Set 2 | kushima
# Processing Record 27 of Set 2 | xapuri
# Processing Record 28 of Set 2 | karratha
# Processing Record 29 of Set 2 | bredasdorp
# Processing Record 30 of Set 2 | newcastle
# Processing Record 31 of Set 2 | mayumba
# Processing Record 32 of Set 2 | fortuna
# Processing Record 33 of Set 2 | port alfred
# Processing Record 34 of Set 2 | ucluelet
# Processing Record 35 of Set 2 | isangel
# Processing Record 36 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 38 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 2 | te anau
# Processing Record 40 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 2 | mali idos
# City not found. Skipping...
# Processing Record 42 of Set 2 | poum
# Processing Record 43 of Set 2 | souillac
# Processing Record 44 of Set 2 | port lincoln
# Processing Record 45 of Set 2 | miguel alves
# Processing Record 46 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 2 | bilgoraj
# Processing Record 48 of Set 2 | washington
# Processing Record 49 of Set 2 | umm jarr
# City not found. Skipping...
# Processing Record 50 of Set 2 | saint-paul
# Processing Record 1 of Set 3 | ajdabiya
# Processing Record 2 of Set 3 | san jose
# Processing Record 3 of Set 3 | ducheng
# Processing Record 4 of Set 3 | seoul
# Processing Record 5 of Set 3 | narsaq
# Processing Record 6 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 7 of Set 3 | port elizabeth
# Processing Record 8 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 3 | vao
# Processing Record 10 of Set 3 | hilo
# Processing Record 11 of Set 3 | puerto ayora
# Processing Record 12 of Set 3 | salekhard
# Processing Record 13 of Set 3 | aleksandriyskaya
# Processing Record 14 of Set 3 | kindu
# Processing Record 15 of Set 3 | saint anthony
# Processing Record 16 of Set 3 | portland
# Processing Record 17 of Set 3 | russell
# Processing Record 18 of Set 3 | chuy
# Processing Record 19 of Set 3 | lebu
# Processing Record 20 of Set 3 | luwuk
# Processing Record 21 of Set 3 | dickinson
# Processing Record 22 of Set 3 | chany
# Processing Record 23 of Set 3 | khandyga
# Processing Record 24 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 25 of Set 3 | sembe
# Processing Record 26 of Set 3 | beringovskiy
# Processing Record 27 of Set 3 | sabang
# Processing Record 28 of Set 3 | terney
# Processing Record 29 of Set 3 | guerrero negro
# Processing Record 30 of Set 3 | tagusao
# Processing Record 31 of Set 3 | sur
# Processing Record 32 of Set 3 | dwarka
# Processing Record 33 of Set 3 | campbell river
# Processing Record 34 of Set 3 | maniitsoq
# Processing Record 35 of Set 3 | qaanaaq
# Processing Record 36 of Set 3 | clonakilty
# Processing Record 37 of Set 3 | narasannapeta
# Processing Record 38 of Set 3 | severnoye
# Processing Record 39 of Set 3 | along
# Processing Record 40 of Set 3 | port moresby
# Processing Record 41 of Set 3 | konstanz
# Processing Record 42 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 3 | cabo san lucas
# Processing Record 44 of Set 3 | saskylakh
# Processing Record 45 of Set 3 | san patricio
# Processing Record 46 of Set 3 | urulga
# City not found. Skipping...
# Processing Record 47 of Set 3 | vaini
# Processing Record 48 of Set 3 | maumere
# Processing Record 49 of Set 3 | lavrentiya
# Processing Record 50 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 4 | bilma
# Processing Record 2 of Set 4 | touros
# Processing Record 3 of Set 4 | carnarvon
# Processing Record 4 of Set 4 | torbay
# Processing Record 5 of Set 4 | saint-ambroise
# Processing Record 6 of Set 4 | alofi
# Processing Record 7 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 4 | gornopravdinsk
# Processing Record 9 of Set 4 | novobelokatay
# Processing Record 10 of Set 4 | pevek
# Processing Record 11 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 4 | severo-kurilsk
# Processing Record 13 of Set 4 | adrar
# Processing Record 14 of Set 4 | shipunovo
# Processing Record 15 of Set 4 | avarua
# Processing Record 16 of Set 4 | ostrovnoy
# Processing Record 17 of Set 4 | tuatapere
# Processing Record 18 of Set 4 | mumbwa
# Processing Record 19 of Set 4 | saint-philippe
# Processing Record 20 of Set 4 | acajutla
# Processing Record 21 of Set 4 | yulara
# Processing Record 22 of Set 4 | hasaki
# Processing Record 23 of Set 4 | victoria
# Processing Record 24 of Set 4 | mao
# Processing Record 25 of Set 4 | ribeira grande
# Processing Record 26 of Set 4 | mogadishu
# Processing Record 27 of Set 4 | chandbali
# Processing Record 28 of Set 4 | waingapu
# Processing Record 29 of Set 4 | san juan
# Processing Record 30 of Set 4 | kudahuvadhoo
# Processing Record 31 of Set 4 | mangla
# Processing Record 32 of Set 4 | winslow
# Processing Record 33 of Set 4 | mayo
# Processing Record 34 of Set 4 | tiksi
# Processing Record 35 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 4 | thompson
# Processing Record 37 of Set 4 | nome
# Processing Record 38 of Set 4 | mocuba
# Processing Record 39 of Set 4 | port hawkesbury
# Processing Record 40 of Set 4 | buluang
# Processing Record 41 of Set 4 | saldanha
# Processing Record 42 of Set 4 | salym
# Processing Record 43 of Set 4 | faanui
# Processing Record 44 of Set 4 | monrovia
# Processing Record 45 of Set 4 | yellowknife
# Processing Record 46 of Set 4 | lorengau
# Processing Record 47 of Set 4 | mar del plata
# Processing Record 48 of Set 4 | upernavik
# Processing Record 49 of Set 4 | andenes
# Processing Record 50 of Set 4 | fort nelson
# Processing Record 1 of Set 5 | clyde river
# Processing Record 2 of Set 5 | sobolevo
# Processing Record 3 of Set 5 | vila velha
# Processing Record 4 of Set 5 | uray
# Processing Record 5 of Set 5 | marica
# Processing Record 6 of Set 5 | stornoway
# Processing Record 7 of Set 5 | vanimo
# Processing Record 8 of Set 5 | obanazawa
# Processing Record 9 of Set 5 | umm lajj
# Processing Record 10 of Set 5 | broome
# Processing Record 11 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 5 | jamestown
# Processing Record 13 of Set 5 | mayskiy
# Processing Record 14 of Set 5 | vorsma
# Processing Record 15 of Set 5 | krasnoselkup
# Processing Record 16 of Set 5 | gorno-altaysk
# Processing Record 17 of Set 5 | padang
# Processing Record 18 of Set 5 | bagdarin
# Processing Record 19 of Set 5 | nyurba
# Processing Record 20 of Set 5 | san julian
# Processing Record 21 of Set 5 | yar-sale
# Processing Record 22 of Set 5 | zhigansk
# Processing Record 23 of Set 5 | bethel
# Processing Record 24 of Set 5 | luderitz
# Processing Record 25 of Set 5 | aswan
# Processing Record 26 of Set 5 | kavieng
# Processing Record 27 of Set 5 | humberto de campos
# Processing Record 28 of Set 5 | hanko
# Processing Record 29 of Set 5 | poquoson
# Processing Record 30 of Set 5 | ponta do sol
# Processing Record 31 of Set 5 | coos bay
# Processing Record 32 of Set 5 | manokwari
# Processing Record 33 of Set 5 | kodiak
# Processing Record 34 of Set 5 | port blair
# Processing Record 35 of Set 5 | paamiut
# Processing Record 36 of Set 5 | san vicente
# Processing Record 37 of Set 5 | wonthaggi
# Processing Record 38 of Set 5 | makakilo city
# Processing Record 39 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 40 of Set 5 | santiago
# Processing Record 41 of Set 5 | hithadhoo
# Processing Record 42 of Set 5 | sinop
# Processing Record 43 of Set 5 | rakai
# Processing Record 44 of Set 5 | tulum
# Processing Record 45 of Set 5 | la vega
# Processing Record 46 of Set 5 | mount darwin
# Processing Record 47 of Set 5 | kloulklubed
# Processing Record 48 of Set 5 | longyearbyen
# Processing Record 49 of Set 5 | shenjiamen
# Processing Record 50 of Set 5 | pacific grove
# Processing Record 1 of Set 6 | ranong
# Processing Record 2 of Set 6 | kahului
# Processing Record 3 of Set 6 | imbituba
# Processing Record 4 of Set 6 | samarai
# Processing Record 5 of Set 6 | luanda
# Processing Record 6 of Set 6 | basoda
# Processing Record 7 of Set 6 | klaksvik
# Processing Record 8 of Set 6 | airai
# Processing Record 9 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 6 | phalaborwa
# Processing Record 11 of Set 6 | ler
# Processing Record 12 of Set 6 | bay roberts
# Processing Record 13 of Set 6 | pasni
# Processing Record 14 of Set 6 | cherskiy
# Processing Record 15 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 6 | jalu
# Processing Record 17 of Set 6 | korhogo
# Processing Record 18 of Set 6 | prado
# Processing Record 19 of Set 6 | moiyabana
# City not found. Skipping...
# Processing Record 20 of Set 6 | igarka
# Processing Record 21 of Set 6 | the valley
# Processing Record 22 of Set 6 | aberdeen
# Processing Record 23 of Set 6 | jiuquan
# Processing Record 24 of Set 6 | nola
# Processing Record 25 of Set 6 | lata
# Processing Record 26 of Set 6 | sucre
# Processing Record 27 of Set 6 | ludvika
# Processing Record 28 of Set 6 | sistranda
# Processing Record 29 of Set 6 | sao filipe
# Processing Record 30 of Set 6 | arraial do cabo
# Processing Record 31 of Set 6 | vardo
# Processing Record 32 of Set 6 | boden
# Processing Record 33 of Set 6 | san cristobal
# Processing Record 34 of Set 6 | rocha
# Processing Record 35 of Set 6 | carbonia
# Processing Record 36 of Set 6 | mahebourg
# Processing Record 37 of Set 6 | kenai
# Processing Record 38 of Set 6 | iquique
# Processing Record 39 of Set 6 | rundu
# Processing Record 40 of Set 6 | los cordobas
# Processing Record 41 of Set 6 | naryan-mar
# Processing Record 42 of Set 6 | kundiawa
# Processing Record 43 of Set 6 | zambezi
# Processing Record 44 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 45 of Set 6 | japura
# Processing Record 46 of Set 6 | datong
# Processing Record 47 of Set 6 | plouzane
# Processing Record 48 of Set 6 | norman wells
# Processing Record 49 of Set 6 | chicama
# Processing Record 50 of Set 6 | polson
# Processing Record 1 of Set 7 | okhotsk
# Processing Record 2 of Set 7 | san marco in lamis
# Processing Record 3 of Set 7 | mangrol
# Processing Record 4 of Set 7 | gurskoye
# City not found. Skipping...
# Processing Record 5 of Set 7 | abu dhabi
# Processing Record 6 of Set 7 | makinsk
# Processing Record 7 of Set 7 | iqaluit
# Processing Record 8 of Set 7 | chifeng
# Processing Record 9 of Set 7 | meulaboh
# Processing Record 10 of Set 7 | xuddur
# Processing Record 11 of Set 7 | nagorsk
# Processing Record 12 of Set 7 | klyuchi
# Processing Record 13 of Set 7 | navrongo
# Processing Record 14 of Set 7 | ewa beach
# Processing Record 15 of Set 7 | leh
# Processing Record 16 of Set 7 | viksoyri
# City not found. Skipping...
# Processing Record 17 of Set 7 | nigran
# Processing Record 18 of Set 7 | marsh harbour
# Processing Record 19 of Set 7 | kirakira
# Processing Record 20 of Set 7 | voyvozh
# Processing Record 21 of Set 7 | horta
# Processing Record 22 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 7 | semey
# Processing Record 24 of Set 7 | ahipara
# Processing Record 25 of Set 7 | buribay
# Processing Record 26 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 7 | synya
# Processing Record 28 of Set 7 | shouguang
# Processing Record 29 of Set 7 | leningradskiy
# Processing Record 30 of Set 7 | treinta y tres
# Processing Record 31 of Set 7 | mikhaylovka
# Processing Record 32 of Set 7 | hofn
# Processing Record 33 of Set 7 | nemuro
# Processing Record 34 of Set 7 | bengkulu
# Processing Record 35 of Set 7 | katherine
# Processing Record 36 of Set 7 | bar harbor
# Processing Record 37 of Set 7 | elat
# Processing Record 38 of Set 7 | totma
# Processing Record 39 of Set 7 | ozernovskiy
# Processing Record 40 of Set 7 | whitehorse
# Processing Record 41 of Set 7 | tezu
# Processing Record 42 of Set 7 | tautira
# Processing Record 43 of Set 7 | kinkala
# Processing Record 44 of Set 7 | khormuj
# City not found. Skipping...
# Processing Record 45 of Set 7 | maues
# Processing Record 46 of Set 7 | ukholovo
# Processing Record 47 of Set 7 | baykit
# Processing Record 48 of Set 7 | tokur
# Processing Record 49 of Set 7 | tambovka
# Processing Record 50 of Set 7 | warrnambool
# Processing Record 1 of Set 8 | muisne
# Processing Record 2 of Set 8 | wenling
# Processing Record 3 of Set 8 | miles city
# Processing Record 4 of Set 8 | husavik
# Processing Record 5 of Set 8 | yerbogachen
# Processing Record 6 of Set 8 | kimbe
# Processing Record 7 of Set 8 | puerto quijarro
# Processing Record 8 of Set 8 | tomatlan
# Processing Record 9 of Set 8 | abu samrah
# Processing Record 10 of Set 8 | yumen
# Processing Record 11 of Set 8 | birao
# Processing Record 12 of Set 8 | mabay
# Processing Record 13 of Set 8 | atambua
# Processing Record 14 of Set 8 | darhan
# Processing Record 15 of Set 8 | podbelsk
# City not found. Skipping...
# Processing Record 16 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 17 of Set 8 | sao jose do calcado
# Processing Record 18 of Set 8 | ust-nera
# Processing Record 19 of Set 8 | bemidji
# Processing Record 20 of Set 8 | taft
# Processing Record 21 of Set 8 | khromtau
# Processing Record 22 of Set 8 | maragogi
# Processing Record 23 of Set 8 | segezha
# Processing Record 24 of Set 8 | saint-pierre
# Processing Record 25 of Set 8 | pangnirtung
# Processing Record 26 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 27 of Set 8 | teacapan
# Processing Record 28 of Set 8 | oistins
# Processing Record 29 of Set 8 | chokurdakh
# Processing Record 30 of Set 8 | cordoba
# Processing Record 31 of Set 8 | smithers
# Processing Record 32 of Set 8 | launceston
# Processing Record 33 of Set 8 | purranque
# Processing Record 34 of Set 8 | hamilton
# Processing Record 35 of Set 8 | mana
# Processing Record 36 of Set 8 | rjukan
# Processing Record 37 of Set 8 | vanino
# Processing Record 38 of Set 8 | villazon
# Processing Record 39 of Set 8 | uppsala
# Processing Record 40 of Set 8 | laguna
# Processing Record 41 of Set 8 | vidim
# Processing Record 42 of Set 8 | coahuayana
# Processing Record 43 of Set 8 | hurup
# Processing Record 44 of Set 8 | darya khan
# Processing Record 45 of Set 8 | katobu
# Processing Record 46 of Set 8 | ixtapa
# Processing Record 47 of Set 8 | yuncheng
# Processing Record 48 of Set 8 | gat
# Processing Record 49 of Set 8 | port-gentil
# Processing Record 50 of Set 8 | mount gambier
# Processing Record 1 of Set 9 | hanting
# Processing Record 2 of Set 9 | kiama
# Processing Record 3 of Set 9 | mount isa
# Processing Record 4 of Set 9 | kavaratti
# Processing Record 5 of Set 9 | aviles
# Processing Record 6 of Set 9 | lolodorf
# Processing Record 7 of Set 9 | north platte
# Processing Record 8 of Set 9 | port macquarie
# Processing Record 9 of Set 9 | banepa
# Processing Record 10 of Set 9 | tabou
# Processing Record 11 of Set 9 | vagur
# Processing Record 12 of Set 9 | byron bay
# Processing Record 13 of Set 9 | sisimiut
# Processing Record 14 of Set 9 | locri
# Processing Record 15 of Set 9 | toora-khem
# Processing Record 16 of Set 9 | bathsheba
# Processing Record 17 of Set 9 | batagay-alyta
# Processing Record 18 of Set 9 | kysyl-syr
# Processing Record 19 of Set 9 | kamenka
# Processing Record 20 of Set 9 | lompoc
# Processing Record 21 of Set 9 | anchorage
# Processing Record 22 of Set 9 | englewood
# Processing Record 23 of Set 9 | codrington
# Processing Record 24 of Set 9 | itarema
# Processing Record 25 of Set 9 | mahonda
# Processing Record 26 of Set 9 | porto velho
# Processing Record 27 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 28 of Set 9 | boende
# Processing Record 29 of Set 9 | labytnangi
# Processing Record 30 of Set 9 | carballo
# Processing Record 31 of Set 9 | barabai
# Processing Record 32 of Set 9 | sumisip
# Processing Record 33 of Set 9 | college
# Processing Record 34 of Set 9 | nanakuli
# Processing Record 35 of Set 9 | dunedin
# Processing Record 36 of Set 9 | mackay
# Processing Record 37 of Set 9 | ceres
# Processing Record 38 of Set 9 | tessalit
# Processing Record 39 of Set 9 | kuching
# Processing Record 40 of Set 9 | san policarpo
# Processing Record 41 of Set 9 | oum hadjer
# Processing Record 42 of Set 9 | aykhal
# Processing Record 43 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 44 of Set 9 | vila do maio
# Processing Record 45 of Set 9 | am timan
# Processing Record 46 of Set 9 | barbastro
# Processing Record 47 of Set 9 | comodoro rivadavia
# Processing Record 48 of Set 9 | namatanai
# Processing Record 49 of Set 9 | fukue
# Processing Record 50 of Set 9 | najran
# Processing Record 1 of Set 10 | haines junction
# Processing Record 2 of Set 10 | hualmay
# Processing Record 3 of Set 10 | solok
# Processing Record 4 of Set 10 | berck
# Processing Record 5 of Set 10 | roebourne
# Processing Record 6 of Set 10 | gorontalo
# Processing Record 7 of Set 10 | midland
# Processing Record 8 of Set 10 | bremervorde
# Processing Record 9 of Set 10 | gerash
# Processing Record 10 of Set 10 | apatou
# Processing Record 11 of Set 10 | nizhniy kuranakh
# Processing Record 12 of Set 10 | mancio lima
# Processing Record 13 of Set 10 | sioux lookout
# Processing Record 14 of Set 10 | ancud
# Processing Record 15 of Set 10 | ipojuca
# Processing Record 16 of Set 10 | buncrana
# Processing Record 17 of Set 10 | richards bay
# Processing Record 18 of Set 10 | rivers
# Processing Record 19 of Set 10 | conakry
# Processing Record 20 of Set 10 | grindavik
# Processing Record 21 of Set 10 | rancho palos verdes
# Processing Record 22 of Set 10 | saint-leu
# Processing Record 23 of Set 10 | puerto rondon
# Processing Record 24 of Set 10 | lerwick
# Processing Record 25 of Set 10 | bulgan
# Processing Record 26 of Set 10 | katsuura
# Processing Record 27 of Set 10 | grafton
# Processing Record 28 of Set 10 | yamada
# Processing Record 29 of Set 10 | awbari
# Processing Record 30 of Set 10 | puerto escondido
# Processing Record 31 of Set 10 | killybegs
# Processing Record 32 of Set 10 | kousseri
# Processing Record 33 of Set 10 | gandajika
# Processing Record 34 of Set 10 | nouadhibou
# Processing Record 35 of Set 10 | marfino
# Processing Record 36 of Set 10 | horasan
# Processing Record 37 of Set 10 | mandan
# Processing Record 38 of Set 10 | westport
# Processing Record 39 of Set 10 | sikasso
# Processing Record 40 of Set 10 | nabire
# Processing Record 41 of Set 10 | gornyatskiy
# Processing Record 42 of Set 10 | cayenne
# Processing Record 43 of Set 10 | viedma
# Processing Record 44 of Set 10 | srednekolymsk
# Processing Record 45 of Set 10 | enshi
# Processing Record 46 of Set 10 | qesarya
# Processing Record 47 of Set 10 | roma
# Processing Record 48 of Set 10 | deputatskiy
# Processing Record 49 of Set 10 | minervino murge
# Processing Record 50 of Set 10 | chadiza
# Processing Record 1 of Set 11 | cochrane
# Processing Record 2 of Set 11 | la palma
# Processing Record 3 of Set 11 | muswellbrook
# Processing Record 4 of Set 11 | katsiveli
# City not found. Skipping...
# Processing Record 5 of Set 11 | henties bay
# Processing Record 6 of Set 11 | santa lucia
# Processing Record 7 of Set 11 | kawhia
# Processing Record 8 of Set 11 | necochea
# Processing Record 9 of Set 11 | doka
# Processing Record 10 of Set 11 | bac lieu
# Processing Record 11 of Set 11 | golden
# Processing Record 12 of Set 11 | liancheng
# Processing Record 13 of Set 11 | hami
# Processing Record 14 of Set 11 | thinadhoo
# Processing Record 15 of Set 11 | vostok
# Processing Record 16 of Set 11 | eydhafushi
# Processing Record 17 of Set 11 | gurupi
# Processing Record 18 of Set 11 | nkhotakota
# Processing Record 19 of Set 11 | trairi
# Processing Record 20 of Set 11 | strezhevoy
# Processing Record 21 of Set 11 | izhma
# Processing Record 22 of Set 11 | beidao
# Processing Record 23 of Set 11 | dakar
# Processing Record 24 of Set 11 | san luis
# Processing Record 25 of Set 11 | finnsnes
# Processing Record 26 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 27 of Set 11 | constitucion
# Processing Record 28 of Set 11 | sidi bu zayd
# City not found. Skipping...
# Processing Record 29 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 30 of Set 11 | burnie
# Processing Record 31 of Set 11 | bangkalan
# Processing Record 32 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 33 of Set 11 | belaya gora
# Processing Record 34 of Set 11 | rincon
# Processing Record 35 of Set 11 | pangody
# Processing Record 36 of Set 11 | taoudenni
# Processing Record 37 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 38 of Set 11 | perama
# Processing Record 39 of Set 11 | kenner
# Processing Record 40 of Set 11 | asau
# Processing Record 41 of Set 11 | narayanganj
# Processing Record 42 of Set 11 | haapiti
# Processing Record 43 of Set 11 | bouna
# Processing Record 44 of Set 11 | north bend
# Processing Record 45 of Set 11 | izvoarele sucevei
# Processing Record 46 of Set 11 | malinovskiy
# Processing Record 47 of Set 11 | verkhoyansk
# Processing Record 48 of Set 11 | awjilah
# Processing Record 49 of Set 11 | roros
# Processing Record 50 of Set 11 | marrakesh
# Processing Record 1 of Set 12 | armash
# Processing Record 2 of Set 12 | mehamn
# Processing Record 3 of Set 12 | abatskoye
# Processing Record 4 of Set 12 | los llanos de aridane
# Processing Record 5 of Set 12 | thurso
# Processing Record 6 of Set 12 | macomb
# Processing Record 7 of Set 12 | puerto del rosario
# Processing Record 8 of Set 12 | makokou
# Processing Record 9 of Set 12 | praia
# Processing Record 10 of Set 12 | ouango
# Processing Record 11 of Set 12 | mozarlandia
# Processing Record 12 of Set 12 | storsteinnes
# Processing Record 13 of Set 12 | poli
# Processing Record 14 of Set 12 | paragominas
# Processing Record 15 of Set 12 | chiquilistlan
# Processing Record 16 of Set 12 | boyolangu
# Processing Record 17 of Set 12 | taltal
# Processing Record 18 of Set 12 | villarrobledo
# Processing Record 19 of Set 12 | vikulovo
# Processing Record 20 of Set 12 | brae
# Processing Record 21 of Set 12 | walvis bay
# Processing Record 22 of Set 12 | lodwar
# Processing Record 23 of Set 12 | diffa
# Processing Record 24 of Set 12 | bambous virieux
# Processing Record 25 of Set 12 | zakharovo
# Processing Record 26 of Set 12 | nanton
# Processing Record 27 of Set 12 | aberfeldy
# Processing Record 28 of Set 12 | bungu
# Processing Record 29 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 30 of Set 12 | bocaranga
# City not found. Skipping...
# Processing Record 31 of Set 12 | maloy
# Processing Record 32 of Set 12 | qasigiannguit
# Processing Record 33 of Set 12 | kurilsk
# Processing Record 34 of Set 12 | mezen
# Processing Record 35 of Set 12 | saint combs
# City not found. Skipping...
# Processing Record 36 of Set 12 | ibra
# Processing Record 37 of Set 12 | shieli
# Processing Record 38 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 39 of Set 12 | coquimbo
# Processing Record 40 of Set 12 | grand-santi
# Processing Record 41 of Set 12 | cidreira
# Processing Record 42 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 12 | veraval
# Processing Record 44 of Set 12 | batak
# Processing Record 45 of Set 12 | tynda
# Processing Record 46 of Set 12 | ust-ishim
# Processing Record 47 of Set 12 | dawei
# Processing Record 48 of Set 12 | banjar
# Processing Record 49 of Set 12 | gaoua
# Processing Record 50 of Set 12 | mehran
# Processing Record 1 of Set 13 | safakulevo
# Processing Record 2 of Set 13 | kargil
# Processing Record 3 of Set 13 | nuuk
# Processing Record 4 of Set 13 | baton rouge
# Processing Record 5 of Set 13 | moctezuma
# Processing Record 6 of Set 13 | tabuk
# Processing Record 7 of Set 13 | betanzos
# Processing Record 8 of Set 13 | port augusta
# Processing Record 9 of Set 13 | orapa
# Processing Record 10 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 11 of Set 13 | evensk
# Processing Record 12 of Set 13 | jacareacanga
# Processing Record 13 of Set 13 | oranjemund
# Processing Record 14 of Set 13 | neiafu
# Processing Record 15 of Set 13 | myitkyina
# Processing Record 16 of Set 13 | nasrullaganj
# City not found. Skipping...
# Processing Record 17 of Set 13 | tilichiki
# Processing Record 18 of Set 13 | virginia beach
# Processing Record 19 of Set 13 | lakes entrance
# Processing Record 20 of Set 13 | purpe
# Processing Record 21 of Set 13 | loralai
# Processing Record 22 of Set 13 | fairbanks
# Processing Record 23 of Set 13 | mahibadhoo
# Processing Record 24 of Set 13 | hambantota
# Processing Record 25 of Set 13 | salinas
# Processing Record 26 of Set 13 | kaniama
# Processing Record 27 of Set 13 | benguela
# Processing Record 28 of Set 13 | quatre cocos
# Processing Record 29 of Set 13 | valdivia
# Processing Record 30 of Set 13 | paralimni
# Processing Record 31 of Set 13 | ordzhonikidze
# Processing Record 32 of Set 13 | tamiahua
# Processing Record 33 of Set 13 | sandnessjoen
# Processing Record 34 of Set 13 | galveston
# Processing Record 35 of Set 13 | brownsville
# Processing Record 36 of Set 13 | mednogorsk
# Processing Record 37 of Set 13 | mantua
# Processing Record 38 of Set 13 | tarko-sale
# Processing Record 39 of Set 13 | tafresh
# Processing Record 40 of Set 13 | coolum beach
# Processing Record 41 of Set 13 | saint-georges
# Processing Record 42 of Set 13 | cururupu
# Processing Record 43 of Set 13 | kursenai
# Processing Record 44 of Set 13 | alice springs
# Processing Record 45 of Set 13 | honolulu
# Processing Record 46 of Set 13 | atlantic beach
# Processing Record 47 of Set 13 | ha giang
# Processing Record 48 of Set 13 | soyo
# Processing Record 49 of Set 13 | port hedland
# Processing Record 50 of Set 13 | bud
# Processing Record 1 of Set 14 | hervey bay
# Processing Record 2 of Set 14 | dengzhou
# Processing Record 3 of Set 14 | sovetskiy
# Processing Record 4 of Set 14 | wajima
# Processing Record 5 of Set 14 | llanes
# Processing Record 6 of Set 14 | puerto asis
# Processing Record 7 of Set 14 | ladario
# Processing Record 8 of Set 14 | axim
# Processing Record 9 of Set 14 | hovd
# Processing Record 10 of Set 14 | tazovskiy
# Processing Record 11 of Set 14 | cam pha
# City not found. Skipping...
# Processing Record 12 of Set 14 | regeneracao
# Processing Record 13 of Set 14 | maryborough
# Processing Record 14 of Set 14 | pandan
# Processing Record 15 of Set 14 | palmer
# Processing Record 16 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 14 | kosamba
# Processing Record 18 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 19 of Set 14 | aklavik
# Processing Record 20 of Set 14 | kuryk
# Processing Record 21 of Set 14 | wazzan
# City not found. Skipping...
# Processing Record 22 of Set 14 | pedernales
# Processing Record 23 of Set 14 | buala
# Processing Record 24 of Set 14 | sainte-savine
# Processing Record 25 of Set 14 | panjab
# Processing Record 26 of Set 14 | karachi
# Processing Record 27 of Set 14 | sterling
# Processing Record 28 of Set 14 | karakol
# Processing Record 29 of Set 14 | senno
# Processing Record 30 of Set 14 | bafoulabe
# Processing Record 31 of Set 14 | eyl
# Processing Record 32 of Set 14 | flin flon
# Processing Record 33 of Set 14 | caravelas
# Processing Record 34 of Set 14 | nea playia
# Processing Record 35 of Set 14 | lander
# Processing Record 36 of Set 14 | judaberg
# Processing Record 37 of Set 14 | bowen
# Processing Record 38 of Set 14 | faya
# Processing Record 39 of Set 14 | beruwala
# Processing Record 40 of Set 14 | balkhash
# Processing Record 41 of Set 14 | natagaima
# Processing Record 42 of Set 14 | kikwit
# Processing Record 43 of Set 14 | conceicao do araguaia
# Processing Record 44 of Set 14 | talnakh
# Processing Record 45 of Set 14 | ozgon
# City not found. Skipping...
# Processing Record 46 of Set 14 | farsund
# Processing Record 47 of Set 14 | santa maria del oro
# Processing Record 48 of Set 14 | tomball
# Processing Record 49 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 50 of Set 14 | bom jesus
# Processing Record 1 of Set 15 | divnomorskoye
# Processing Record 2 of Set 15 | wejherowo
# Processing Record 3 of Set 15 | hastings
# Processing Record 4 of Set 15 | gualeguay
# Processing Record 5 of Set 15 | diego de almagro
# Processing Record 6 of Set 15 | emerald
# Processing Record 7 of Set 15 | niceville
# Processing Record 8 of Set 15 | moron
# Processing Record 9 of Set 15 | yeehaw junction
# City not found. Skipping...
# Processing Record 10 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 11 of Set 15 | qandahar
# City not found. Skipping...
# Processing Record 12 of Set 15 | sitka
# Processing Record 13 of Set 15 | vengerovo
# Processing Record 14 of Set 15 | nara
# Processing Record 15 of Set 15 | markova
# Processing Record 16 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 17 of Set 15 | berlevag
# Processing Record 18 of Set 15 | buraydah
# Processing Record 19 of Set 15 | kokkola
# Processing Record 20 of Set 15 | mikkeli
# Processing Record 21 of Set 15 | kurri kurri
# Processing Record 22 of Set 15 | bandarbeyla
# Processing Record 23 of Set 15 | bima
# Processing Record 24 of Set 15 | panubigan
# Processing Record 25 of Set 15 | nijar
# Processing Record 26 of Set 15 | lumeje
# Processing Record 27 of Set 15 | sa kaeo
# Processing Record 28 of Set 15 | antofagasta
# Processing Record 29 of Set 15 | tecoanapa
# Processing Record 30 of Set 15 | yatou
# Processing Record 31 of Set 15 | ngaoundere
# Processing Record 32 of Set 15 | salalah
# Processing Record 33 of Set 15 | tubuala
# Processing Record 34 of Set 15 | quelimane
# Processing Record 35 of Set 15 | sabla
# Processing Record 36 of Set 15 | kathu
# Processing Record 37 of Set 15 | akdepe
# Processing Record 38 of Set 15 | sao miguel do araguaia
# Processing Record 39 of Set 15 | saint-augustin
# Processing Record 40 of Set 15 | sretensk
# Processing Record 41 of Set 15 | mahajanga
# Processing Record 42 of Set 15 | bahia blanca
# Processing Record 43 of Set 15 | novovasylivka
# Processing Record 44 of Set 15 | kapit
# Processing Record 45 of Set 15 | calvinia
# Processing Record 46 of Set 15 | mabaruma
# Processing Record 47 of Set 15 | ayame
# Processing Record 48 of Set 15 | northam
# Processing Record 49 of Set 15 | pak phanang
# Processing Record 50 of Set 15 | gizo
# Processing Record 1 of Set 16 | amuntai
# Processing Record 2 of Set 16 | bela cruz
# Processing Record 3 of Set 16 | nichinan
# Processing Record 4 of Set 16 | camacha
# Processing Record 5 of Set 16 | svetlaya
# Processing Record 6 of Set 16 | klyuchevskiy
# Processing Record 7 of Set 16 | kamskiye polyany
# Processing Record 8 of Set 16 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 16 | tigre
# Processing Record 10 of Set 16 | sulzbach-rosenberg
# Processing Record 11 of Set 16 | qobustan
# Processing Record 12 of Set 16 | szczytno
# Processing Record 13 of Set 16 | kachiry
# Processing Record 14 of Set 16 | kismayo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura -46.1927  168.8643     40.48        94         100
# 1     Duminichi  53.9345   35.1099     65.71        96          87
# 2  Punta Arenas -53.1500  -70.9167     48.31        53          75
# 3       Ushuaia -54.8000  -68.3000     47.86        57           0
# 4        Rawson -43.3002  -65.1023     47.30        57          58
# 5      Flinders -34.5833  150.8552     48.25        72          45
# 6       Kapoeta   4.7717   33.5903     85.03        35          91
# 7      Hermanus -34.4187   19.2345     57.79        70          87
# 8         Kapaa  22.0752 -159.3190     79.12        73          75
# 9          Naze  28.3667  129.4833     74.80        94         100
#
#    Wind Speed Country   Current Description
# 0       12.06      NZ       overcast clouds
# 1        6.22      RU  heavy intensity rain
# 2       10.36      CL         broken clouds
# 3        4.61      AR             clear sky
# 4       12.37      AR         broken clouds
# 5        6.89      AU      scattered clouds
# 6       17.45      SS       overcast clouds
# 7       18.59      ZA       overcast clouds
# 8        5.75      US         broken clouds
# 9       19.15      JP         moderate rain

# %%
# Create the output file (CSV).
output_data_file = "/Users/jkstuff/Desktop/Data Analytics/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
